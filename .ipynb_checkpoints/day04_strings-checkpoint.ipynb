# %%
a = 'string'
b = 'another string'
print(a, b)
# Out:
# string another string

# %%
print(a + b)
# Out:
# stringanother string

# %%
print(a)
print(b)
# Out:
# string
# another string

# %%
print(a + '\n' + b) #print in two different lines
# Out:
# string
# another string

# %%
print(a)
'''
multiline
comment
'''
print(b)
# Out:
# string
# another string

# %%
print("123" + "42")
# Out:
# 12342

# %%
a = int(input())
b = int(input())
c = int(input())
p = (a + b + c) / 2
print((p * (p-a) * (p-b) * (p-c)) ** 0.5)
# Out:
#  3
#  4
#  5
# 6.0
